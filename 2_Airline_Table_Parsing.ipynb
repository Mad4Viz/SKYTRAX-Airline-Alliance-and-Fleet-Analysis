# %% [markdown]
# # Airline Data Parser
# This notebook contains a parser to convert HTML airline tables into structured data format.
#
# ## Setup Requirements
# - Python 3.9.6
# - Required packages: beautifulsoup4, pandas
# - Input file: airline_data.html with airline tables

# %%
# Import required libraries
import pandas as pd
from bs4 import BeautifulSoup
import re
from datetime import datetime
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %% [markdown]
# ## AirlineHTMLParser Class
# This class handles the parsing of airline HTML data into structured format.
#
# Key features:
# - Reads HTML file containing multiple airline tables
# - Extracts individual airline sections
# - Standardizes dates to DD/MM/YYYY format
# - Parses table data into structured format
# - Exports data to CSV

# %%
class AirlineHTMLParser:
    """
    Parser for converting HTML airline tables into structured data format
    """
    
    def __init__(self, input_file='airline_data.html'):
        """Initialize parser with input file path"""
        self.input_file = input_file
    
    def read_html_file(self):
        """Read the HTML file containing airline tables"""
        try:
            with open(self.input_file, 'r', encoding='utf-8') as file:
                return file.read()
        except Exception as e:
            logging.error(f"Error reading file {self.input_file}: {e}")
            return None
            
    def extract_airline_sections(self, html_content):
        """Extract individual airline sections from HTML content"""
        pattern = r'<!-- START AIRLINE: (.*?) -->(.*?)<!-- END AIRLINE:'
        matches = re.finditer(pattern, html_content, re.DOTALL)
        
        airline_sections = []
        for match in matches:
            airline_name = match.group(1)
            airline_html = match.group(2)
            airline_sections.append((airline_name, airline_html))
            
        return airline_sections
        
    def standardize_date(self, date_str):
        """Convert date string to DD/MM/YYYY format"""
        try:
            date_obj = datetime.strptime(date_str, '%d %b %Y')
            return date_obj.strftime('%d/%m/%Y')
        except ValueError as e:
            logging.warning(f"Could not parse date: {date_str}. Error: {e}")
            return date_str
            
    def parse_airline_table(self, airline_html):
        """Parse individual airline table HTML"""
        soup = BeautifulSoup(airline_html, 'html.parser')
        table = soup.find('table', class_='infobox')
        
        if not table:
            return None
            
        airline_data = {}
        
        # Extract logo URL
        logo_img = table.find('img', class_='airline-logo__img')
        if logo_img and 'src' in logo_img.attrs:
            airline_data['logo_url'] = logo_img['src']
            
        # Extract other information
        for row in table.find_all('tr'):
            cells = row.find_all(['td', 'th'])
            if len(cells) >= 2:
                header = cells[0].text.strip()
                if len(cells) > 2:
                    value = cells[2].text.strip()
                else:
                    value = cells[1].text.strip()
                    
                # Clean up header
                header = header.replace('\n', ' ').strip()
                
                # Handle specific fields
                if header in ['Founded', 'Started Operations']:
                    value = self.standardize_date(value)
                    
                airline_data[header] = value
                
        return airline_data
        
    def process_airlines(self):
        """Process all airlines in the HTML file"""
        html_content = self.read_html_file()
        if not html_content:
            return None
            
        airline_sections = self.extract_airline_sections(html_content)
        all_airlines_data = []
        
        for airline_name, airline_html in airline_sections:
            logging.info(f"Processing airline: {airline_name}")
            airline_data = self.parse_airline_table(airline_html)
            if airline_data:
                airline_data['Airline Name'] = airline_name
                all_airlines_data.append(airline_data)
                
        return pd.DataFrame(all_airlines_data)
        
    def export_to_csv(self, df, filename='parsed_airline_data.csv'):
        """Export DataFrame to CSV"""
        try:
            df.to_csv(filename, index=False)
            logging.info(f"Data successfully exported to {filename}")
        except Exception as e:
            logging.error(f"Error exporting data to CSV: {e}")

# %% [markdown]
# ## Testing the Parser
# Now we'll test the parser with our airline data. Make sure you have created the `airline_data.html` file with the correct format:
#
# ```html
# <!-- START AIRLINE: Qatar Airways -->
# <table class="infobox">
# ... Qatar Airways table content ...
# </table>
# <!-- END AIRLINE: Qatar Airways -->

# %%
# Initialize parser
parser = AirlineHTMLParser('airline_data.html')

# Process airlines and get DataFrame
df = parser.process_airlines()

if df is not None:
    # Display the data
    print("\nExtracted Airline Data:")
    print(df.to_string())
    
    # Export to CSV
    parser.export_to_csv(df)
else:
    print("Error processing airline data")
# Out:
# 2025-01-28 16:44:34,645 - INFO - Processing airline: Qatar Airways
# 2025-01-28 16:44:34,650 - INFO - Processing airline: Singapore Airlines
# 2025-01-28 16:44:34,654 - INFO - Processing airline: Emirates Airlines
# 2025-01-28 16:44:34,657 - INFO - Processing airline: All Nippon Airways
# 2025-01-28 16:44:34,661 - WARNING - Could not parse date: Dec 1957. Error: time data 'Dec 1957' does not match format '%d %b %Y'
# 2025-01-28 16:44:34,662 - INFO - Processing airline: Cathay Pacific Airways
# 2025-01-28 16:44:34,666 - INFO - Processing airline: Japan Airlines
# 2025-01-28 16:44:34,670 - INFO - Processing airline: Turkish Airlines
# 2025-01-28 16:44:34,673 - INFO - Processing airline: EVA Air
# 2025-01-28 16:44:34,677 - INFO - Processing airline: Air France
# 2025-01-28 16:44:34,682 - INFO - Processing airline: Swiss International Air Lines
# 2025-01-28 16:44:34,713 - INFO - Data successfully exported to parsed_airline_data.csv
# Extracted Airline Data:
#                                                                             logo_url          IATAQR                           Full Name               Country     Founded Started Operations      Group / Part of                          Headquarters                               Main Hub                                               Fleet Size Average Fleet Age 1        Official Site                   Airline Name             IATASQ                                                                                                                  Predecessors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Subsidiaries                Base / Main Hub            IATAEK              IATANH                                        Predecessor                                                                                                                                                                                                                                                                                                                                                                      Bases          IATACX            IATAJL           IATATK       IATABR                                                                                                             Focus Cities            IATAAF         IATALX
# 0         https://assets.planespotters.net/files/airlines/8/qatar-airways_59d08b.svg  CallsignQATARI      Qatar Airways Company Q.C.S.C.                 Qatar  22/11/1993         20/01/1994  Qatar Airways Group                                  Doha  Doha Hamad International (DOH / OTHH)  227 Aircraft                    (+ 11 On Order/Planned)           9.7 Years     qatarairways.com                  Qatar Airways                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 1    https://assets.planespotters.net/files/airlines/5/singapore-airlines_921743.svg             NaN                                 NaN             Singapore  01/05/1947                NaN                  NaN                                   NaN                                    NaN   158 Aircraft                    (+ 5 On Order/Planned)           7.9 Years     singaporeair.com             Singapore Airlines  CallsignSINGAPORE                                                               Malaysia-Singapore Airlines (ML / MSA)\n\n\n SilkAir (MI / SLK)  Air India\n                                                                                                                                    (202 aircraft)\n                                                            \n\n Scoot\n                                                                                                                                    (55 aircraft)\n                                                            \n\n SilkAir\n\n\n Singapore Airlines Cargo\n\n\n Tradewinds\n\n\n Vistara  Singapore Changi (SIN / WSSS)               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 2                 https://assets.planespotters.net/files/airlines/4/emirates_opk.jpg             NaN                    Emirates Airline  United Arab Emirates  25/03/1985         25/10/1985   The Emirates Group                                 Dubai       Dubai International (DXB / OMDB)  260 Aircraft                    (+ 22 On Order/Planned)          10.9 Years         emirates.com              Emirates Airlines                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN  CallsignEMIRATES                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 3    https://assets.planespotters.net/files/airlines/8/all-nippon-airways_705169.svg             NaN  All Nippon Airways Company Limited                 Japan  27/12/1952           Dec 1957            ANA Group                                 Tokyo                                    NaN  239 Aircraft                    (+ 13 On Order/Planned)          11.1 Years            ana.co.jp             All Nippon Airways                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN  CallsignALL NIPPON  Japan Helicopter and Aeroplane Transports Company                                                                                             Tokyo Haneda (HND / RJTT)                                                    \n\n Tokyo Narita (NRT / RJAA)                                                    \n\n Osaka Itami (ITM / RJOO)                                                    \n\n Osaka Kansai (KIX / RJBB)             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 4        https://assets.planespotters.net/files/airlines/8/cathay-pacific_84333f.svg             NaN      Cathay Pacific Airways Limited             Hong Kong  24/09/1946                NaN         Cathay Group                             Hong Kong    Hong Kong Chek Lap Kok (HKG / VHHH)                                             179 Aircraft            12 Years    cathaypacific.com         Cathay Pacific Airways                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN  CallsignCATHAY               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 5    https://assets.planespotters.net/files/airlines/7/japan-airlines_2decbc_opr.png             NaN      Japan Airlines Company Limited                 Japan  01/08/1951         25/10/1951            JAL Group                                 Tokyo                                    NaN   149 Aircraft                    (+ 2 On Order/Planned)          11.9 Years              jal.com                 Japan Airlines                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                 Japan Airlines Domestic (JL / JFL)  Osaka Itami (ITM / RJOO)                                                    \n\n Osaka Kansai (KIX / RJBB)                                                    \n\n Nagoya Chubu Centrair (NGO / RJGG)                                                    \n\n Tokyo Haneda (HND / RJTT)                                                    \n\n Tokyo Narita (NRT / RJAA)             NaN  CallsignJAPANAIR              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 6  https://assets.planespotters.net/files/airlines/6/turkish-airlines_da1e4f_opk.jpg             NaN              Türk Hava Yollari A.O.               Türkiye  20/05/1933                NaN                  NaN         Istanbul Ataturk (ISL / LTBA)      Istanbul New Airport (IST / LTFM)  374 Aircraft                    (+ 11 On Order/Planned)           9.1 Years  turkishairlines.com               Turkish Airlines                NaN                                                                                                                           NaN                                     AJet\n                                                                                                                                    (85 aircraft)\n                                                            \n\n AnadoluJet\n\n\n SunExpress\n                                                                                                                                    (72 aircraft)\n                                                            \n\n SunExpress Germany                            NaN               NaN                 NaN                   Turkish Air Transport (ZH / THT)                                                                                                                                                        Antalya (AYT / LTAI)                                                    \n\n Ankara Esenboga (ESB / LTAC)                                                    \n\n Istanbul Sabiha Gökçen International (SAW / LTFJ)             NaN               NaN  CallsignTURKISH          NaN                                                                                                                      NaN               NaN            NaN
# 7       https://assets.planespotters.net/files/airlines/9/eva-airways_516c2c_opr.png             NaN             EVA Airways Corporation                Taiwan  08/03/1989         01/07/1991      Evergreen Group                          Taoyuan City            Taipei Taoyuan (TPE / RCTP)    84 Aircraft                    (+ 5 On Order/Planned)             9 Years           evaair.com                        EVA Air                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN  CallsignEVA                                                                                        Bangkok Suvarnabhumi (BKK / VTBS)               NaN            NaN
# 8            https://assets.planespotters.net/files/airlines/6/air-france_45ae1c.svg             NaN                      Air France-KLM                France  07/10/1933                NaN       Air France-KLM  Paris Charles De Gaulle (CDG / LFPG)                                    NaN   226 Aircraft                    (+ 2 On Order/Planned)          12.6 Years        airfrance.com                     Air France                NaN  Air France Air Inter Express (AF)\n\n\n Air France Asie (AF)\n\n\n Air France Express (AF)\n\n\n Air Inter Europe (IT / ITF)                                                                                                                                                                                                                                                                                                                                                                                                                                      Air France Air Inter Express\n\n\n Air France Asie\n\n\n Air France Express\n\n\n Euroberlin                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                      Paris Orly (ORY / LFPO)                                                    \n\n Pointe-a-Pitre Le Raizet (PTP / TFFR)             NaN               NaN              NaN          NaN  Lyon Saint Exupery (LYS / LFLL)                                                    \n\n Marseille Provence (MRS / LFML)  CallsignAIRFRANS            NaN
# 9                 https://assets.planespotters.net/files/airlines/9/swiss_8c838e.svg             NaN  Swiss International Air Lines Ltd.           Switzerland  31/03/2002                NaN      Lufthansa Group                                   NaN                                    NaN    89 Aircraft                    (+ 6 On Order/Planned)          11.8 Years            swiss.com  Swiss International Air Lines                NaN                 Crossair (LX / CRX)\n\n\n Crossair Europe (QE / ECC)\n\n\n Swiss Global (LX / SWU)\n\n\n Swiss Sun (LX / SWR)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Swiss Sun     Zurich Kloten (ZRH / LSZH)               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                             Geneva Cointrin (GVA / LSGG)               NaN  CallsignSWISS

# %%
# Initialize parser
parser = AirlineHTMLParser('airline_data.html')

# Check if file exists
import os
if not os.path.exists('airline_data.html'):
    print("Error: airline_data.html file not found!")
    print("Current working directory:", os.getcwd())
else:
    # Process airlines and get DataFrame
    html_content = parser.read_html_file()
    if html_content is None:
        print("Error: Could not read HTML file")
    elif not html_content.strip():
        print("Error: HTML file is empty")
    else:
        print("File read successfully, length:", len(html_content))
        
        df = parser.process_airlines()
        
        if df is not None:
            # Display the data
            print("\nExtracted Airline Data:")
            print(df.to_string())
            
            # Export to CSV
            parser.export_to_csv(df)
        else:
            print("Error: Could not process airline data")
# Out:
# 2025-01-28 16:44:35,865 - INFO - Processing airline: Qatar Airways
# 2025-01-28 16:44:35,869 - INFO - Processing airline: Singapore Airlines
# 2025-01-28 16:44:35,873 - INFO - Processing airline: Emirates Airlines
# 2025-01-28 16:44:35,877 - INFO - Processing airline: All Nippon Airways
# 2025-01-28 16:44:35,880 - WARNING - Could not parse date: Dec 1957. Error: time data 'Dec 1957' does not match format '%d %b %Y'
# 2025-01-28 16:44:35,881 - INFO - Processing airline: Cathay Pacific Airways
# 2025-01-28 16:44:35,884 - INFO - Processing airline: Japan Airlines
# 2025-01-28 16:44:35,887 - INFO - Processing airline: Turkish Airlines
# 2025-01-28 16:44:35,890 - INFO - Processing airline: EVA Air
# 2025-01-28 16:44:35,893 - INFO - Processing airline: Air France
# 2025-01-28 16:44:35,897 - INFO - Processing airline: Swiss International Air Lines
# 2025-01-28 16:44:35,943 - INFO - Data successfully exported to parsed_airline_data.csv
# File read successfully, length: 56185
#
# Extracted Airline Data:
#                                                                             logo_url          IATAQR                           Full Name               Country     Founded Started Operations      Group / Part of                          Headquarters                               Main Hub                                               Fleet Size Average Fleet Age 1        Official Site                   Airline Name             IATASQ                                                                                                                  Predecessors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Subsidiaries                Base / Main Hub            IATAEK              IATANH                                        Predecessor                                                                                                                                                                                                                                                                                                                                                                      Bases          IATACX            IATAJL           IATATK       IATABR                                                                                                             Focus Cities            IATAAF         IATALX
# 0         https://assets.planespotters.net/files/airlines/8/qatar-airways_59d08b.svg  CallsignQATARI      Qatar Airways Company Q.C.S.C.                 Qatar  22/11/1993         20/01/1994  Qatar Airways Group                                  Doha  Doha Hamad International (DOH / OTHH)  227 Aircraft                    (+ 11 On Order/Planned)           9.7 Years     qatarairways.com                  Qatar Airways                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 1    https://assets.planespotters.net/files/airlines/5/singapore-airlines_921743.svg             NaN                                 NaN             Singapore  01/05/1947                NaN                  NaN                                   NaN                                    NaN   158 Aircraft                    (+ 5 On Order/Planned)           7.9 Years     singaporeair.com             Singapore Airlines  CallsignSINGAPORE                                                               Malaysia-Singapore Airlines (ML / MSA)\n\n\n SilkAir (MI / SLK)  Air India\n                                                                                                                                    (202 aircraft)\n                                                            \n\n Scoot\n                                                                                                                                    (55 aircraft)\n                                                            \n\n SilkAir\n\n\n Singapore Airlines Cargo\n\n\n Tradewinds\n\n\n Vistara  Singapore Changi (SIN / WSSS)               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 2                 https://assets.planespotters.net/files/airlines/4/emirates_opk.jpg             NaN                    Emirates Airline  United Arab Emirates  25/03/1985         25/10/1985   The Emirates Group                                 Dubai       Dubai International (DXB / OMDB)  260 Aircraft                    (+ 22 On Order/Planned)          10.9 Years         emirates.com              Emirates Airlines                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN  CallsignEMIRATES                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 3    https://assets.planespotters.net/files/airlines/8/all-nippon-airways_705169.svg             NaN  All Nippon Airways Company Limited                 Japan  27/12/1952           Dec 1957            ANA Group                                 Tokyo                                    NaN  239 Aircraft                    (+ 13 On Order/Planned)          11.1 Years            ana.co.jp             All Nippon Airways                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN  CallsignALL NIPPON  Japan Helicopter and Aeroplane Transports Company                                                                                             Tokyo Haneda (HND / RJTT)                                                    \n\n Tokyo Narita (NRT / RJAA)                                                    \n\n Osaka Itami (ITM / RJOO)                                                    \n\n Osaka Kansai (KIX / RJBB)             NaN               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 4        https://assets.planespotters.net/files/airlines/8/cathay-pacific_84333f.svg             NaN      Cathay Pacific Airways Limited             Hong Kong  24/09/1946                NaN         Cathay Group                             Hong Kong    Hong Kong Chek Lap Kok (HKG / VHHH)                                             179 Aircraft            12 Years    cathaypacific.com         Cathay Pacific Airways                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN  CallsignCATHAY               NaN              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 5    https://assets.planespotters.net/files/airlines/7/japan-airlines_2decbc_opr.png             NaN      Japan Airlines Company Limited                 Japan  01/08/1951         25/10/1951            JAL Group                                 Tokyo                                    NaN   149 Aircraft                    (+ 2 On Order/Planned)          11.9 Years              jal.com                 Japan Airlines                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                 Japan Airlines Domestic (JL / JFL)  Osaka Itami (ITM / RJOO)                                                    \n\n Osaka Kansai (KIX / RJBB)                                                    \n\n Nagoya Chubu Centrair (NGO / RJGG)                                                    \n\n Tokyo Haneda (HND / RJTT)                                                    \n\n Tokyo Narita (NRT / RJAA)             NaN  CallsignJAPANAIR              NaN          NaN                                                                                                                      NaN               NaN            NaN
# 6  https://assets.planespotters.net/files/airlines/6/turkish-airlines_da1e4f_opk.jpg             NaN              Türk Hava Yollari A.O.               Türkiye  20/05/1933                NaN                  NaN         Istanbul Ataturk (ISL / LTBA)      Istanbul New Airport (IST / LTFM)  374 Aircraft                    (+ 11 On Order/Planned)           9.1 Years  turkishairlines.com               Turkish Airlines                NaN                                                                                                                           NaN                                     AJet\n                                                                                                                                    (85 aircraft)\n                                                            \n\n AnadoluJet\n\n\n SunExpress\n                                                                                                                                    (72 aircraft)\n                                                            \n\n SunExpress Germany                            NaN               NaN                 NaN                   Turkish Air Transport (ZH / THT)                                                                                                                                                        Antalya (AYT / LTAI)                                                    \n\n Ankara Esenboga (ESB / LTAC)                                                    \n\n Istanbul Sabiha Gökçen International (SAW / LTFJ)             NaN               NaN  CallsignTURKISH          NaN                                                                                                                      NaN               NaN            NaN
# 7       https://assets.planespotters.net/files/airlines/9/eva-airways_516c2c_opr.png             NaN             EVA Airways Corporation                Taiwan  08/03/1989         01/07/1991      Evergreen Group                          Taoyuan City            Taipei Taoyuan (TPE / RCTP)    84 Aircraft                    (+ 5 On Order/Planned)             9 Years           evaair.com                        EVA Air                NaN                                                                                                                           NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN  CallsignEVA                                                                                        Bangkok Suvarnabhumi (BKK / VTBS)               NaN            NaN
# 8            https://assets.planespotters.net/files/airlines/6/air-france_45ae1c.svg             NaN                      Air France-KLM                France  07/10/1933                NaN       Air France-KLM  Paris Charles De Gaulle (CDG / LFPG)                                    NaN   226 Aircraft                    (+ 2 On Order/Planned)          12.6 Years        airfrance.com                     Air France                NaN  Air France Air Inter Express (AF)\n\n\n Air France Asie (AF)\n\n\n Air France Express (AF)\n\n\n Air Inter Europe (IT / ITF)                                                                                                                                                                                                                                                                                                                                                                                                                                      Air France Air Inter Express\n\n\n Air France Asie\n\n\n Air France Express\n\n\n Euroberlin                            NaN               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                      Paris Orly (ORY / LFPO)                                                    \n\n Pointe-a-Pitre Le Raizet (PTP / TFFR)             NaN               NaN              NaN          NaN  Lyon Saint Exupery (LYS / LFLL)                                                    \n\n Marseille Provence (MRS / LFML)  CallsignAIRFRANS            NaN
# 9                 https://assets.planespotters.net/files/airlines/9/swiss_8c838e.svg             NaN  Swiss International Air Lines Ltd.           Switzerland  31/03/2002                NaN      Lufthansa Group                                   NaN                                    NaN    89 Aircraft                    (+ 6 On Order/Planned)          11.8 Years            swiss.com  Swiss International Air Lines                NaN                 Crossair (LX / CRX)\n\n\n Crossair Europe (QE / ECC)\n\n\n Swiss Global (LX / SWU)\n\n\n Swiss Sun (LX / SWR)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Swiss Sun     Zurich Kloten (ZRH / LSZH)               NaN                 NaN                                                NaN                                                                                                                                                                                                                                                                                                                                                                        NaN             NaN               NaN              NaN          NaN                                                                                             Geneva Cointrin (GVA / LSGG)               NaN  CallsignSWISS
